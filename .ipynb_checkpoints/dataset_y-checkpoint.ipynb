# %%
from sklearn.datasets import make_regression, make_classification, make_blobs
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd
import seaborn as sns
import tensorflow as tf
import math
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping
import xgboost as xgb

# %%
# How to create a dataset for a regression problem
from sklearn.datasets import make_regression
X, y = make_regression(n_samples=100000, n_features=10, noise=1, random_state=42)

# %%
X.shape
# Out:
# (100000, 10)

# %%
# View the some sample rows classification dataset
X=pd.DataFrame(X,
             columns=["x"+ str(i) for i in range(X.shape[1])])

# %%
X.shape
# Out:
# (100000, 10)

# %%
X
# Out:
#              x0        x1        x2        x3        x4        x5        x6  \
# 0      0.513684 -0.663305 -0.406961  0.941686  0.080072 -0.707402 -1.452069
# 1      0.694633 -0.625742  0.290747  0.436807  0.353729  0.316013 -1.359967
# 2     -0.706068 -0.732100 -0.399617 -0.486119 -1.354954 -0.952421 -0.726255
# 3     -2.073925 -0.434403  0.923416 -0.345848  0.652079  0.387707  2.112640
# 4     -0.297383  0.500332  0.134989 -0.461432  0.080355 -0.493411 -0.506790
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  1.807580 -0.275631  0.612627  2.382403 -0.537025  0.259139  0.315484
# 99996  0.018383 -0.202521  1.177962  0.555344 -2.132862  1.192824 -0.638527
# 99997 -1.034895 -0.024536  0.534377 -0.819797 -0.830068 -1.609765 -0.405299
# 99998 -2.289487 -0.111614  1.607214 -1.299463 -0.354723  0.033740 -1.871111
# 99999  1.074307  0.413430 -0.661532 -0.031149 -2.705239 -0.375815 -0.711350
#
#              x7        x8        x9
# 0     -0.096950  0.258669 -1.698373
# 1     -1.142611  1.693408 -0.925918
# 2     -0.162429 -0.331205  0.304091
# 3      0.899307  0.475307 -1.081995
# 4      0.208156  1.602062  1.219711
# ...         ...       ...       ...
# 99995  0.349820  0.640789  1.755819
# 99996  0.122774 -1.587905 -0.159498
# 99997  0.565865  1.064393 -1.489664
# 99998  0.504355  1.133523  1.896814
# 99999 -0.475086 -0.086901  1.012724
#
# [100000 rows x 10 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   x0      100000 non-null  float64
#  1   x1      100000 non-null  float64
#  2   x2      100000 non-null  float64
#  3   x3      100000 non-null  float64
#  4   x4      100000 non-null  float64
#  5   x5      100000 non-null  float64
#  6   x6      100000 non-null  float64
#  7   x7      100000 non-null  float64
#  8   x8      100000 non-null  float64
#  9   x9      100000 non-null  float64
# dtypes: float64(10)
# memory usage: 7.6 MB

# %%
X.describe()
# Out:
#                   x0             x1             x2             x3  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       -0.009174      -0.006189      -0.001087      -0.002651
# std         1.002777       1.002022       0.999204       0.999876
# min        -4.413886      -4.829436      -4.462969      -4.164295
# 25%        -0.685038      -0.686381      -0.675554      -0.678496
# 50%        -0.005213      -0.006546       0.003023      -0.005605
# 75%         0.663199       0.669070       0.678210       0.672416
# max         4.479084       4.004674       4.153257       4.065773
#
#                   x4             x5             x6             x7  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       -0.000910      -0.000077       0.004144      -0.000298
# std         1.001490       0.998152       1.002926       0.997781
# min        -4.295391      -4.157734      -4.465604      -4.319465
# 25%        -0.676449      -0.678283      -0.671899      -0.676117
# 50%        -0.001011      -0.000383       0.001894       0.003220
# 75%         0.670100       0.672049       0.679716       0.675479
# max         3.859376       4.289893       4.616384       4.678949
#
#                   x8             x9
# count  100000.000000  100000.000000
# mean       -0.000217       0.000462
# std         0.997511       1.000111
# min        -4.596948      -3.984321
# 25%        -0.669209      -0.674383
# 50%        -0.000557       0.000833
# 75%         0.674237       0.676583
# max         4.526784       3.989945

# %%
X['y'] = X.apply(lambda row: row.x1/(row.x2*row.x3)-
                                  (row.x4*5)+math.tan(row.x5)+row.x7+math.sin(row.x6)+row.x8/row.x9+(row.x0), axis = 1)

# %%
X
# Out:
#              x0        x1        x2        x3        x4        x5        x6  \
# 0      0.513684 -0.663305 -0.406961  0.941686  0.080072 -0.707402 -1.452069
# 1      0.694633 -0.625742  0.290747  0.436807  0.353729  0.316013 -1.359967
# 2     -0.706068 -0.732100 -0.399617 -0.486119 -1.354954 -0.952421 -0.726255
# 3     -2.073925 -0.434403  0.923416 -0.345848  0.652079  0.387707  2.112640
# 4     -0.297383  0.500332  0.134989 -0.461432  0.080355 -0.493411 -0.506790
# ...         ...       ...       ...       ...       ...       ...       ...
# 99995  1.807580 -0.275631  0.612627  2.382403 -0.537025  0.259139  0.315484
# 99996  0.018383 -0.202521  1.177962  0.555344 -2.132862  1.192824 -0.638527
# 99997 -1.034895 -0.024536  0.534377 -0.819797 -0.830068 -1.609765 -0.405299
# 99998 -2.289487 -0.111614  1.607214 -1.299463 -0.354723  0.033740 -1.871111
# 99999  1.074307  0.413430 -0.661532 -0.031149 -2.705239 -0.375815 -0.711350
#
#              x7        x8        x9          y
# 0     -0.096950  0.258669 -1.698373  -0.253081
# 1     -1.142611  1.693408 -0.925918  -9.623491
# 2     -0.162429 -0.331205  0.304091  -1.021164
# 3      0.899307  0.475307 -1.081995  -2.248944
# 4      0.208156  1.602062  1.219711  -8.233209
# ...         ...       ...       ...        ...
# 99995  0.349820  0.640789  1.755819   5.594002
# 99996  0.122774 -1.587905 -0.159498  22.373988
# 99997  0.565865  1.064393 -1.489664  28.276828
# 99998  0.504355  1.133523  1.896814  -0.281972
# 99999 -0.475086 -0.086901  1.012724  33.055388
#
# [100000 rows x 11 columns]

# %%
#min_threshold,max_threshold=X.y.quantile([0.001,0.97])
min_threshold,max_threshold=X.y.quantile([0.03,0.97])
min_threshold,max_threshold
# Out:
# (-63.690638284538956, 60.91910919601071)

# %%
X[X.y<min_threshold]
# Out:
#              x0        x1        x2        x3        x4        x5        x6  \
# 16    -0.399970  2.075315  0.010227 -0.027528  1.164889 -0.979269  0.117880
# 24     1.087578 -1.437642  0.169170  0.000989  1.509560  0.340068  0.005260
# 29     1.666589  1.971351  0.677767 -0.586694  0.116877 -1.558230 -0.205429
# 41    -1.983829  1.612078  0.191530 -0.076478  0.202341  0.125124  1.986227
# 99    -0.043941 -0.657648 -0.135248 -0.063544 -0.178445 -1.448699  1.406492
# ...         ...       ...       ...       ...       ...       ...       ...
# 99832  0.863912  1.403379 -0.082735  0.075388 -1.635954 -0.213174 -0.488940
# 99874 -0.407417 -2.566508 -0.032561 -0.221684 -0.145441  0.442531  1.089538
# 99912  0.731721  1.603327  0.111227 -0.112904 -0.482923  0.351830 -0.225633
# 99927 -0.050294  0.789202  0.211096 -0.056801  0.108803 -0.418717  0.086689
# 99983  0.650002 -0.740815  0.006280  1.403501  0.428835 -1.310365  0.018349
#
#              x7        x8        x9            y
# 16    -0.532288 -0.051286  1.339850 -7379.779628
# 24     1.521156  1.406751 -0.164219 -8609.482437
# 29     0.265006  0.865375  0.241323   -79.801026
# 41    -0.360931  0.147909 -0.982554  -112.522770
# 99     0.438521  0.946986  0.817691   -81.240623
# ...         ...       ...       ...          ...
# 99832  0.010145  2.394906 -0.924840  -219.219763
# 99874 -0.263447 -1.638020  0.884214  -355.996778
# 99912  1.145851 -1.079492  2.075475  -123.758888
# 99927 -0.459290 -1.362011  0.538259   -69.761508
# 99983 -0.707855 -1.385291  0.016826  -172.311682
#
# [3000 rows x 11 columns]

# %%
X[X.y>max_threshold]
# Out:
#              x0        x1        x2        x3        x4        x5        x6  \
# 7      0.847000 -1.632504 -1.071834  1.292323  0.920303  1.553240  0.683921
# 33    -2.150864  0.638999 -0.013582 -0.116682  0.075159 -0.052947 -1.211756
# 45    -0.438586 -0.662484 -0.010847  0.460021 -0.966283 -1.126260 -1.184365
# 49     0.489203 -2.405943 -2.381767  0.014960  0.195849 -1.931959  0.768008
# 103    0.564309 -1.006719 -0.176192  0.044758  1.383520  0.443541 -0.507842
# ...         ...       ...       ...       ...       ...       ...       ...
# 99824  0.592870 -0.551570 -0.007877  0.722920 -0.134204  0.071642 -0.032623
# 99913  1.333993 -1.239379  0.525055 -0.030616 -1.241929 -0.231865 -0.586201
# 99938  1.854869  0.668748  0.254646 -1.022282 -1.555774  0.718238 -0.570932
# 99947 -0.800507 -1.520431  0.046725 -0.540600 -1.832173 -1.739931  1.890917
# 99978  0.357019 -0.025038 -0.784302  0.000101  0.488684  0.162243  1.031995
#
#              x7        x8        x9           y
# 7      0.086712  1.180382  0.135955   63.778035
# 33     0.297376 -1.197822 -0.496592  402.412764
# 45    -0.547682  1.055167  1.409509  134.334766
# 49    -0.042487  0.342285  1.125339   70.639078
# 103    0.858499  0.187404 -0.341867  121.605067
# ...         ...       ...       ...         ...
# 99824 -0.107908 -1.272670  1.718609   97.316531
# 99913  1.895138  1.108616  0.945149   86.922254
# 99938  0.935813  2.409467  0.028410   93.145870
# 99947  0.818058 -0.536518  0.653245   75.354920
# 99978  0.100343 -0.630198  0.567855  312.943219
#
# [3000 rows x 11 columns]

# %%
X=X[X.y<max_threshold]
X.shape
# Out:
# (97000, 11)

# %%
X=X[X.y>min_threshold]
X.shape
# Out:
# (94000, 11)

# %%
#min_threshold,max_threshold=X.y.quantile([0.001,0.97])
min_threshold,max_threshold=X.x6.quantile([0.03,0.97])
min_threshold,max_threshold
# Out:
# (-1.8816603271720382, 1.889198364454312)

# %%
X[X.x6<min_threshold]
# Out:
#              x0        x1        x2        x3        x4        x5        x6  \
# 51     2.113347  1.138220  0.157327 -1.993174  0.425455  0.132458 -2.042993
# 159    0.428179 -1.136888 -0.350801 -0.592700  2.132172 -0.084769 -2.667396
# 176   -0.802366  0.061611  1.463741  0.768200  0.310736  0.030522 -2.017117
# 198    0.194142  1.330843 -0.438737 -0.761504  1.126010  0.637450 -1.970556
# 236   -1.625187  1.187144  0.096179 -1.074619 -0.482218  0.093447 -2.101294
# ...         ...       ...       ...       ...       ...       ...       ...
# 99867  0.563410 -0.137212 -0.412161 -0.633789  0.300175  0.173824 -1.979330
# 99889 -0.053225  1.223189  2.428820 -0.949633 -0.611291 -0.214522 -2.385160
# 99903 -0.618880  1.524162 -0.387737 -1.246705  0.706717 -0.342315 -1.935085
# 99933 -0.586421  0.673843  0.150746 -1.107657 -0.892122 -0.558366 -2.198263
# 99980  2.613077  0.357041 -0.334070  0.596784  1.329245 -0.875211 -2.145036
#
#              x7        x8        x9          y
# 51     0.129955 -1.804931  0.048691 -41.340266
# 159    0.205412 -0.654003 -0.504804 -14.741225
# 176    1.667680 -0.389639 -0.841845  -1.042245
# 198    1.476182 -1.192750 -0.209096   5.547400
# 236   -0.462486 -0.618207  1.167384 -12.460997
# ...         ...       ...       ...        ...
# 99867 -0.540763 -0.162912 -0.636731  -2.489747
# 99889 -0.248787  1.388297 -0.692189  -0.685750
# 99903 -0.318748  0.528349 -0.200886  -5.238982
# 99933 -0.665988 -0.966941  0.162845  -8.199366
# 99980  0.198559 -0.440469 -0.659952  -6.995571
#
# [2820 rows x 11 columns]

# %%
X[X.x6>max_threshold]
# Out:
#              x0        x1        x2        x3        x4        x5        x6  \
# 3     -2.073925 -0.434403  0.923416 -0.345848  0.652079  0.387707  2.112640
# 6     -0.318989 -0.390183 -0.822850  0.509689  1.331469 -0.802602  2.072017
# 15     0.533823 -0.761856  1.451576  0.555043  0.720370 -0.600776  2.516203
# 21     0.473981  0.246471 -0.403850  0.054826  0.561744  0.334873  1.919314
# 52    -0.104379 -0.194600 -1.602908  0.490216 -0.476853 -0.493686  2.419198
# ...         ...       ...       ...       ...       ...       ...       ...
# 99754 -0.332161  0.303098  0.235916 -0.418470  0.206158  0.032166  1.997942
# 99810 -0.743970 -1.254216  0.693074  1.355060  0.015492 -1.591736  2.068703
# 99835 -1.453954  0.506142 -0.148546 -0.666613  0.576277  0.815007  2.028773
# 99837  2.296707  1.223947  0.976744  0.812356  0.568405 -1.342458  2.180890
# 99941  0.496382  0.244234  1.717240  2.520120 -1.725244  1.519655  2.002008
#
#              x7        x8        x9          y
# 3      0.899307  0.475307 -1.081995  -2.248944
# 6      0.601229 -1.174772 -1.017535  -4.448253
# 15     0.220451 -1.975210  1.216314  -5.516968
# 21    -0.397971  1.111554 -1.909699 -13.158604
# 52    -0.102060 -1.002988 -0.089821  13.715095
# ...         ...       ...       ...        ...
# 99754  1.778877  0.540870 -0.927826  -2.294846
# 99810  0.652346 -0.609385  0.209659  44.217351
# 99835  0.683150 -0.798367  0.308823   0.832004
# 99837 -2.163022 -0.829883 -1.036369  -3.848547
# 99941 -0.655749  0.463722  0.591336  29.752678
#
# [2820 rows x 11 columns]

# %%
X=X[X.x6<max_threshold]
X.shape
# Out:
# (91180, 11)

# %%
X=X[X.x6>min_threshold]
X.shape
# Out:
# (88360, 11)

# %%
# Vizualize the target dataframe
y=X['y']
X=X.drop(['y'],axis=1)

# %%
y.shape
# Out:
# (88360,)

# %%
plt.figure(figsize=(16,10))
sns.boxplot(X)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(16,10))
sns.boxplot(y)
# Out:
# <Axes: >

# %%
corr = X.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
# Out:
# <Axes: >

# %%
# visiualize all variables  with fare_amount)
from scipy import stats
#creates figure
plt.figure(figsize=(16, 16))

for i, col in enumerate(X.columns[:]): #iterates over all columns except for price column (last one)
    plt.subplot(5, 3, i+1) # each row three figure
    x = X[col] #x-axis
    y = y #y-axis
    plt.xlabel(col)
    plt.ylabel('y')
    plt.plot(x, y, 'o')

# %%
X.shape
# Out:
# (88360, 10)

# %%
print(f"the shape of the inputs x is: {X.shape}")
print(f"the shape of the targets y is: {y.shape}")
# Out:
# the shape of the inputs x is: (88360, 10)
# the shape of the targets y is: (88360,)

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
# Get 70% of the dataset as the training set. Put the remaining 30% in temporary variables: x_ and y_.
X_train, X_, y_train, y_ = train_test_split(X, y, test_size=0.30, random_state=1)

# Split the 30% subset above into two: one half for cross validation and the other for the test set
X_cv, X_test, y_cv, y_test = train_test_split(X_, y_, test_size=0.50, random_state=1)

# Delete temporary variables
#del X_, y_

print(f"the shape of the training set (input) is: {X_train.shape}")
print(f"the shape of the training set (target) is: {y_train.shape}\n")
print(f"the shape of the cross validation set (input) is: {X_cv.shape}")
print(f"the shape of the cross validation set (target) is: {y_cv.shape}\n")
print(f"the shape of the test set (input) is: {X_test.shape}")
print(f"the shape of the test set (target) is: {y_test.shape}")
# Out:
# the shape of the training set (input) is: (61852, 10)
# the shape of the training set (target) is: (61852,)
#
# the shape of the cross validation set (input) is: (13254, 10)
# the shape of the cross validation set (target) is: (13254,)
#
# the shape of the test set (input) is: (13254, 10)
# the shape of the test set (target) is: (13254,)

# %%
import numpy as np
y_train = np.expand_dims(y_train, axis=-1)
y_ = np.expand_dims(y_, axis=-1)
y_test = np.expand_dims(y_test, axis=-1)
y_cv = np.expand_dims(y_cv, axis=-1)

# %%
#Feature Standardization

from sklearn.preprocessing import StandardScaler

# Initialize the class
scaler = StandardScaler()

# Compute the mean and standard deviation of the training set,cv set,test set then transform it
X_train = scaler.fit_transform(X_train)
X_cv = scaler.fit_transform(X_cv)
X_test = scaler.transform(X_test)
X_ = scaler.transform(X_)
y_train = scaler.fit_transform(y_train)
y_cv = scaler.fit_transform(y_cv)
y_test = scaler.transform(y_test)
y_ = scaler.transform(y_)

# %%
X_train
# Out:
# array([[ 0.34581909,  2.98533194,  0.54532575, ...,  2.10017069,
#          0.86485229, -0.89957924],
#        [-0.64336346,  1.17352355,  1.29097462, ..., -1.37002061,
#         -1.89170789, -0.99514947],
#        [-1.08458482,  0.74456543, -1.07122189, ...,  1.54798425,
#          0.66432774,  0.89910204],
#        ...,
#        [ 0.88933403, -0.22426823, -0.75531462, ..., -0.96427993,
#          0.0501826 , -1.62123923],
#        [-0.70155782,  1.97802707,  0.82046234, ...,  0.51087883,
#          2.18668741,  0.99679993],
#        [-0.28712527,  0.04741573,  0.1926657 , ...,  1.36171772,
#         -0.52621071, -0.71052204]])

# %%
y_train
# Out:
# array([[1.07653895],
#        [0.66357342],
#        [0.32922726],
#        ...,
#        [0.28752621],
#        [0.39195507],
#        [0.18448915]])

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
import time

# %%
X_test_new=X_
y_test_new=y_

# %%
X_train_array = np.asarray(X_train)
y_train_array   = np.asarray(y_train)
X_test_new_array = np.asarray(X_test_new)
y_test_new_array   = np.asarray(y_test_new)
print(X_train_array.shape)
print(y_train_array.shape)
# Out:
# (61852, 10)
# (61852, 1)

# %%
lm = LinearRegression()
t0 = time.time()
lm.fit(X_train, y_train)
print("Training time:", time.time()-t0)
# Out:
# Training time: 0.03989243507385254

# %%
lm.coef_
# Out:
# array([[ 0.07015571, -0.00185396, -0.00265947, -0.00234353, -0.33859557,
#          0.04122189,  0.03581133,  0.06989163, -0.00102134,  0.0028379 ]])

# %%
#values from 0 to 1
#0 model explain None of the variability
#1 model explain Entire of the variability
lm.score(X_train,y_train)
# Out:
# 0.1281887264862812

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
# model evaluation for testing set
y_test_predict = lm.predict(X_)
mse = (mean_squared_error(y_, y_test_predict))
rmse=  np.sqrt(mse)
r2 = r2_score(y_, y_test_predict)
#mape=mape(y_, y_test_predict)
#smape=calculate_smape(y_, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
#print('SMAPE score is {}'.format(smape))
# Out:
# The model performance for testing set
# --------------------------------------
# MSE is 0.8814528092676768
# RMSE is 0.9388571825723424
# R2 score is 0.12867395637390622

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_,y_test_predict)
print('MAPE score is {}'.format(mape))
# Out:
# MAPE score is 3.974755387460445

# %% [markdown]
# ## XGBoost

# %%
xg_reg = xgb.XGBRegressor(objective='reg:squarederror', seed=123, n_estimators=10)

# %%
# Fit the regressor to the training set
t0 = time.time()
xg_reg.fit(X_train, y_train)
print("Training time:", time.time()-t0)
# Predict the labels of the test set: preds
preds = xg_reg.predict(X_test)

# compute the rmse: rmse
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# Training time: 1.090083360671997
# RMSE: 0.957701

# %%
# model evaluation for testing set
y_test_predict = xg_reg.predict(X_)
mse = (mean_squared_error(y_, y_test_predict))
rmse=  np.sqrt(mse)
r2 = r2_score(y_, y_test_predict)
#mape=mape(y_, y_test_predict)
#smape=calculate_smape(y_, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
#print('SMAPE score is {}'.format(smape))
# Out:
# The model performance for testing set
# --------------------------------------
# MSE is 0.9106973829870404
# RMSE is 0.954304659418071
# R2 score is 0.09976536541077219

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_,y_test_predict)
print('MAPE score is {}'.format(mape))
# Out:
# MAPE score is 3.9381956608562168

# %% [markdown]
# ## Random Forest

# %%
 from sklearn.ensemble import RandomForestRegressor

# %%
model_ran = RandomForestRegressor(random_state=0)

# %%
y_train_dim = np.squeeze(y_train, axis=-1)
print(y_train_dim.shape)
# Out:
# (61852,)

# %%
t0 = time.time()

# Train the model.
model_ran.fit(X_train,y_train_dim)
print("Training time:", time.time()-t0)
# Out:
# Training time: 245.82899451255798

# %%
# model evaluation for testing set
y_test_predict = model_ran.predict(X_)
mse = (mean_squared_error(y_, y_test_predict))
rmse=  np.sqrt(mse)
r2 = r2_score(y_, y_test_predict)
#smape=calculate_smape(y_, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
#print('SMAPE score is {}'.format(smape))
# Out:
# The model performance for testing set
# --------------------------------------
# MSE is 0.9090840484597001
# RMSE is 0.9534589914934465
# R2 score is 0.1013601647874065

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_,y_test_predict)
print('MAPE score is {}'.format(mape))
# Out:
# MAPE score is 5.212779938519453

# %% [markdown]
# ## Neural Network

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import mean_squared_error

# %%
m=1
N=X_train.shape[0]
L1=np.sqrt((m+2)*N)+2*np.sqrt(N/(m+2))
L1=int(L1)
L2=m*(np.sqrt(N/(m+2)))
L2=int(L2)
print(L1)
print(L2)
# Out:
# 717
# 143

# %%
#get number of columns in training data
n_cols = X_train.shape[1]

# builds model
model3 = Sequential()

model3.add(Dense(L1, activation='relu',input_shape=(n_cols,)))
model3.add(Dense(L2, activation='relu'))

model3.add(Dense(1,activation='linear'))

# %%
#compile model
model3.compile(loss='mse', optimizer='adam', metrics=['mae']) # use metric as mean absolute error

# %%
#inspect the model
model3.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 717)               7887
#
#  dense_10 (Dense)            (None, 143)               102674
#
#  dense_11 (Dense)            (None, 1)                 144
#
# =================================================================
# Total params: 110,705
# Trainable params: 110,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
#train model and perform validation test
import time
early_stop = EarlyStopping(monitor='val_loss', patience=15) # stops training when it doesn't show improvemnet.
t0 = time.time()
history = model3.fit(X_train, y_train, epochs=300,
          validation_data=(X_cv,y_cv), verbose=1, callbacks=[early_stop])
print("Training time:", time.time()-t0)
# Out:
# Epoch 1/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.8761 - mae: 0.5461 - val_loss: 0.8612 - val_mae: 0.5350
# Epoch 2/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.8455 - mae: 0.5261 - val_loss: 0.8268 - val_mae: 0.5228
# Epoch 3/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.7718 - mae: 0.4912 - val_loss: 0.7237 - val_mae: 0.4722
# Epoch 4/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.6522 - mae: 0.4408 - val_loss: 0.6136 - val_mae: 0.4164
# Epoch 5/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.5698 - mae: 0.4071 - val_loss: 0.5599 - val_mae: 0.4082
# Epoch 6/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.5197 - mae: 0.3867 - val_loss: 0.5368 - val_mae: 0.3959
# Epoch 7/300
# 1933/1933 [==============================] - 12s 6ms/step - loss: 0.4902 - mae: 0.3740 - val_loss: 0.4888 - val_mae: 0.3614
# Epoch 8/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.4659 - mae: 0.3623 - val_loss: 0.4810 - val_mae: 0.3728
# Epoch 9/300
# 1933/1933 [==============================] - 8s 4ms/step - loss: 0.4439 - mae: 0.3522 - val_loss: 0.4582 - val_mae: 0.3506
# Epoch 10/300
# 1933/1933 [==============================] - 8s 4ms/step - loss: 0.4216 - mae: 0.3420 - val_loss: 0.4307 - val_mae: 0.3358
# Epoch 11/300
# 1933/1933 [==============================] - 8s 4ms/step - loss: 0.4020 - mae: 0.3302 - val_loss: 0.4223 - val_mae: 0.3343
# Epoch 12/300
# 1933/1933 [==============================] - 8s 4ms/step - loss: 0.3735 - mae: 0.3161 - val_loss: 0.3884 - val_mae: 0.3206
# Epoch 13/300
# 1933/1933 [==============================] - 8s 4ms/step - loss: 0.3545 - mae: 0.3069 - val_loss: 0.3702 - val_mae: 0.3030
# Epoch 14/300
# 1933/1933 [==============================] - 8s 4ms/step - loss: 0.3375 - mae: 0.3011 - val_loss: 0.3909 - val_mae: 0.3347
# Epoch 15/300
# 1933/1933 [==============================] - 8s 4ms/step - loss: 0.3215 - mae: 0.2934 - val_loss: 0.3467 - val_mae: 0.2937
# Epoch 16/300
# 1933/1933 [==============================] - 11s 5ms/step - loss: 0.3089 - mae: 0.2896 - val_loss: 0.3541 - val_mae: 0.3072
# Epoch 17/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.3035 - mae: 0.2871 - val_loss: 0.3162 - val_mae: 0.2768
# Epoch 18/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.2864 - mae: 0.2788 - val_loss: 0.3271 - val_mae: 0.2913
# Epoch 19/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.2806 - mae: 0.2793 - val_loss: 0.3678 - val_mae: 0.3557
# Epoch 20/300
# 1933/1933 [==============================] - 12s 6ms/step - loss: 0.2755 - mae: 0.2748 - val_loss: 0.3286 - val_mae: 0.2953
# Epoch 21/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.2678 - mae: 0.2715 - val_loss: 0.3090 - val_mae: 0.2875
# Epoch 22/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.2603 - mae: 0.2667 - val_loss: 0.2942 - val_mae: 0.2710
# Epoch 23/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.2527 - mae: 0.2640 - val_loss: 0.3236 - val_mae: 0.2971
# Epoch 24/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.2475 - mae: 0.2623 - val_loss: 0.3080 - val_mae: 0.2902
# Epoch 25/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.2446 - mae: 0.2591 - val_loss: 0.3133 - val_mae: 0.2796
# Epoch 26/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.2361 - mae: 0.2532 - val_loss: 0.2944 - val_mae: 0.2781
# Epoch 27/300
# 1933/1933 [==============================] - 12s 6ms/step - loss: 0.2349 - mae: 0.2544 - val_loss: 0.3091 - val_mae: 0.2727
# Epoch 28/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.2311 - mae: 0.2519 - val_loss: 0.2909 - val_mae: 0.2832
# Epoch 29/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.2239 - mae: 0.2473 - val_loss: 0.2933 - val_mae: 0.2733
# Epoch 30/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.2251 - mae: 0.2477 - val_loss: 0.2982 - val_mae: 0.2990
# Epoch 31/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.2183 - mae: 0.2448 - val_loss: 0.2991 - val_mae: 0.3049
# Epoch 32/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.2144 - mae: 0.2437 - val_loss: 0.2763 - val_mae: 0.2650
# Epoch 33/300
# 1933/1933 [==============================] - 12s 6ms/step - loss: 0.2102 - mae: 0.2402 - val_loss: 0.2859 - val_mae: 0.2677
# Epoch 34/300
# 1933/1933 [==============================] - 12s 6ms/step - loss: 0.2080 - mae: 0.2400 - val_loss: 0.2998 - val_mae: 0.2778
# Epoch 35/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.2081 - mae: 0.2401 - val_loss: 0.2813 - val_mae: 0.2647
# Epoch 36/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.1994 - mae: 0.2345 - val_loss: 0.2720 - val_mae: 0.2646
# Epoch 37/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.2006 - mae: 0.2348 - val_loss: 0.2897 - val_mae: 0.2689
# Epoch 38/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.1958 - mae: 0.2314 - val_loss: 0.3004 - val_mae: 0.3083
# Epoch 39/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.1962 - mae: 0.2339 - val_loss: 0.2937 - val_mae: 0.2804
# Epoch 40/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.1933 - mae: 0.2326 - val_loss: 0.2772 - val_mae: 0.2683
# Epoch 41/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.1874 - mae: 0.2292 - val_loss: 0.2912 - val_mae: 0.2683
# Epoch 42/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.1870 - mae: 0.2271 - val_loss: 0.2910 - val_mae: 0.2722
# Epoch 43/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.1877 - mae: 0.2298 - val_loss: 0.2629 - val_mae: 0.2507
# Epoch 44/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.1819 - mae: 0.2253 - val_loss: 0.2706 - val_mae: 0.2706
# Epoch 45/300
# 1933/1933 [==============================] - 11s 5ms/step - loss: 0.1819 - mae: 0.2237 - val_loss: 0.2504 - val_mae: 0.2403
# Epoch 46/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.1815 - mae: 0.2246 - val_loss: 0.2551 - val_mae: 0.2408
# Epoch 47/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.1760 - mae: 0.2208 - val_loss: 0.2438 - val_mae: 0.2364
# Epoch 48/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.1704 - mae: 0.2174 - val_loss: 0.2813 - val_mae: 0.2651
# Epoch 49/300
# 1933/1933 [==============================] - 11s 6ms/step - loss: 0.1712 - mae: 0.2163 - val_loss: 0.2655 - val_mae: 0.2539
# Epoch 50/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.1707 - mae: 0.2177 - val_loss: 0.2742 - val_mae: 0.2737
# Epoch 51/300
# 1933/1933 [==============================] - 8s 4ms/step - loss: 0.1660 - mae: 0.2132 - val_loss: 0.2675 - val_mae: 0.2522
# Epoch 52/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.1646 - mae: 0.2137 - val_loss: 0.2599 - val_mae: 0.2589
# Epoch 53/300
# 1933/1933 [==============================] - 11s 5ms/step - loss: 0.1645 - mae: 0.2154 - val_loss: 0.2743 - val_mae: 0.2477
# Epoch 54/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.1643 - mae: 0.2132 - val_loss: 0.2550 - val_mae: 0.2489
# Epoch 55/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.1600 - mae: 0.2098 - val_loss: 0.2612 - val_mae: 0.2535
# Epoch 56/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.1595 - mae: 0.2114 - val_loss: 0.2524 - val_mae: 0.2414
# Epoch 57/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.1575 - mae: 0.2084 - val_loss: 0.2480 - val_mae: 0.2408
# Epoch 58/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.1590 - mae: 0.2089 - val_loss: 0.2669 - val_mae: 0.2415
# Epoch 59/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.1565 - mae: 0.2072 - val_loss: 0.2577 - val_mae: 0.2350
# Epoch 60/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.1576 - mae: 0.2072 - val_loss: 0.2609 - val_mae: 0.2503
# Epoch 61/300
# 1933/1933 [==============================] - 10s 5ms/step - loss: 0.1495 - mae: 0.2032 - val_loss: 0.2476 - val_mae: 0.2509
# Epoch 62/300
# 1933/1933 [==============================] - 9s 5ms/step - loss: 0.1512 - mae: 0.2050 - val_loss: 0.2461 - val_mae: 0.2395
# Training time: 613.847594499588

# %%
# show the graph of model loss in trainig and validation

plt.figure(figsize=(15,8))
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.plot(history.epoch, history.history['loss'],
           label='Train Loss')
plt.plot(history.epoch, history.history['val_loss'],
           label = 'Val loss')
plt.title('Model loss')
plt.legend()

# %%
#check the model performace in test dataset
score = model3.evaluate(X_train, y_train, verbose=1)

print('Mean square error: ', score[0])

print('Root Mean square error: ', np.sqrt(score[0]))
print('Mean absolute error: ', score[1])
# Out:
# 1933/1933 [==============================] - 6s 3ms/step - loss: 0.1373 - mae: 0.1943
# Mean square error:  0.13734900951385498
# Root Mean square error:  0.3706062729013838
# Mean absolute error:  0.19432780146598816

# %%
#check the model performace in test dataset
score = model3.evaluate(X_test, y_test, verbose=1)

print('Mean square error: ', score[0])

print('Root Mean square error: ', np.sqrt(score[0]))
print('Mean absolute error: ', score[1])
# Out:
# 415/415 [==============================] - 1s 3ms/step - loss: 0.2523 - mae: 0.2428
# Mean square error:  0.25233855843544006
# Root Mean square error:  0.5023331150097912
# Mean absolute error:  0.24281924962997437

# %%
# model evaluation for testing set
y_test_predict = model3.predict(X_)
mse = (mean_squared_error(y_, y_test_predict))
rmse=  np.sqrt(mse)
r2 = r2_score(y_, y_test_predict)
#smape=calculate_smape(y_, y_test_predict)

print("The model performance for testing set")
print("--------------------------------------")
print('MSE is {}'.format(mse))
print('RMSE is {}'.format(rmse))
print('R2 score is {}'.format(r2))
#print('SMAPE score is {}'.format(smape))
# Out:
# 829/829 [==============================] - 2s 2ms/step
# The model performance for testing set
# --------------------------------------
# MSE is 0.24919600976065057
# RMSE is 0.49919536231885264
# R2 score is 0.7536669337380041

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_,y_test_predict)
print('MAPE score is {}'.format(mape))
# Out:
# MAPE score is 3.1829354481300673
